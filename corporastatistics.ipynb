# %% [markdown]
# # Tagrumma n yisefka
# Dagi ad nseqdec afaylu corpus-kab.txt. Afaylu-a yegber tifyar yettwacerḍen s teqbaylit.

# %% [markdown]
# # Tasleḍt n yisefka isnalɣanen iseddasanen

# %% [markdown]
# * Afmiḍi n yismilen inejrumen deg uḍris n ulmdu

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
word_all=[]
words_diffrent=[]
Ponctuation=['...',',',';','?','!',':','"','(',')','*','_','.','[',']','{','}','«','»','+','=','.','$','“','”','-']

#extraction du tableau des tags et initaliser à 0 les occurences

tagpos=[]
occurences=[]
for ligne in open("tagspos.txt",encoding='utf-8'):
    ligne=ligne.strip().replace('\ufeff','')
    tagpos.append(ligne)
for i in tagpos:
    occurences.append(0)

b=""
for ligne in open("corpus-kab.txt",encoding='utf-8'):

     #ligne=ligne.lower()
    ligne=ligne.strip().replace('\ufeff','').replace("\n","")
    
    if ligne != '':
        a=ligne.split(" ")

        for i in a:
          b=i.split("/")
          if(b[1]=='NMP'):
             word_all.append(b[0])
          else:
             word_all.append(b[0].lower())
          occurences[tagpos.index(b[1])]=(occurences[tagpos.index(b[1])]+1)
        #print (c)


for i in word_all:
    if i not in words_diffrent:
        words_diffrent.append(i)
print('Total de mots:',len(word_all),'-> Mots différents',len(words_diffrent))

# calcul du pourcentage d'apparition des de certaines classes


labels=[]
fracs=[]
for i in tagpos:
    # Ne prendre que les classes dont le nombre d'occurence est supérieur à 400 et sans la poctuation
    if (i not in Ponctuation and occurences[tagpos.index(i)] >= 400): 
     labels.append(i)
     fracs.append(occurences[tagpos.index(i)])


patches, texts, autotexts = plt.pie(fracs,
                                    labels=labels, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt.xlabel('Ifmiḍen n yismilen inejrumanen')

##
plt.show()
# Out:
# Total de mots: 18383 -> Mots différents 4334

# %% [markdown]
# * Afmiḍi n usenqeḍ / Awalen

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
word_all=[]
words_diffrent=[]
Ponctuation=['...',',',';','?','!',':','"','(',')','*','_','.','[',']','{','}','«','»','+','=','.','$','“','”','-']

#extraction du tableau des tags et initaliser à 0 les occurences

tagpos=[]
occurences=[]
for ligne in open("tagspos.txt",encoding='utf-8'):
    ligne=ligne.strip().replace('\ufeff','')
    tagpos.append(ligne)
for i in tagpos:
    occurences.append(0)

b=""
for ligne in open("corpus-kab.txt",encoding='utf-8'):

     #ligne=ligne.lower()
    ligne=ligne.strip().replace('\ufeff','').replace("\n","")

    if ligne != '':
        a=ligne.split(" ")

        for i in a:
          b=i.split("/")
          if(b[1]=='NMP'):
             word_all.append(b[0])
          else:
             word_all.append(b[0].lower())
          occurences[tagpos.index(b[1])]=(occurences[tagpos.index(b[1])]+1)
        #print (c)

labels=['PNCT','NOT Ponctuation']
fracs=[]
x=0

#print (tags)
y=0
number_punct=0
number_not_punct=0
for i in tagpos:
    #print (i[0])
    if (i  in Ponctuation):
        number_punct=number_punct+occurences[tagpos.index(i)]
    else:
     number_not_punct=number_not_punct+occurences[tagpos.index(i)]
fracs=[number_punct,number_not_punct]
patches, texts, autotexts = plt.pie(fracs,
                                    labels=labels, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt.xlabel('Ifmiḍen n yisekkilen  d yizamulen n usenqeḍ di teqbaylit')

plt.show()

# %% [markdown]
# * Taille des mots

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
word_all=[]
words_diffrent=[]
Ponctuation=['...',',',';','?','!',':','"','(',')','*','_','.','[',']','{','}','«','»','+','=','.','$','“','”','-']

### calcul du nombre de mots par taille dans le corpus

taille=[]
for i in range(80):
    taille.append(0)
labels=[]

first=0
for ligne in open("corpus-kab.txt",encoding='utf-8'):

    ligne=ligne.strip().replace('\ufeff','').replace("\n","")

    if ligne != '':
     a=ligne.split()

     for i in a:
            b=i.split('/')
            if (b[1] not in Ponctuation):
                taille[len(b[0])-1]=taille[len(b[0])-1]+1

j=1
tail=[]
for i in taille:
    if i!=0:
        #print(i)
        tail.append(i)
        labels.append(str(j))
    j=j+1


patches, texts, autotexts = plt.pie(tail,
                                    labels=labels, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt.xlabel('Ifmiḍen n teɣzi n wawalen deg uḍris n ulmud')

plt.show()

# %% [markdown]
# * Teɣzi n tefyar

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt1
import matplotlib.pyplot as plt2
import numpy as np
from matplotlib import colors
word_all=[]
words_diffrent=[]
Ponctuation=['...',',',';','?','!',':','"','(',')','*','_','.','[',']','{','}','«','»','+','=','.','$','“','”','-']

### calcul du nombre de mots par taille dans le corpus

taille=[]
i=0
while  i<=80:
    taille.append(0)
    i=i+1
labels=[]

first=0
nb=0
for ligne in open("corpus-kab.txt",encoding='utf-8'):

     #ligne=ligne.lower()
    ligne=ligne.strip().replace('\ufeff','').replace("\n","")

    if ligne != '':
     a=ligne.split()
    #print(a)
     nb=0
    for i in a:
            b=i.split('/')
            if (b[1]  in Ponctuation):
                nb=nb+1
            taille[len(a)-nb-1]=taille[len(a)-nb-1]+1
j=1
tail=[]
for i in taille[:len(taille)//3]:
    if i!=0:
        #print(i)
        tail.append(i)
        labels.append(str(j))
    j=j+1


patches, texts, autotexts = plt.pie(tail,
                                    labels=labels, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt.xlabel('Ifmiḍen n teɣzi n tifyar deg uḍris n ulmud')
plt.show()


tail1=[]
labels1=[]
for i in taille[len(taille)//3:2*len(taille)//3]:
    if i!=0:
        #print(i)
        tail1.append(i)
        labels1.append(str(j))
    j=j+1


patches, texts, autotexts = plt.pie(tail1,
                                    labels=labels1, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt1.xlabel('Ifmiḍen n teɣzi n tifyar deg uḍris n ulmud')
plt1.show()


tail2=[]
labels2=[]
for i in taille[2*len(taille)//3:]:
    if i!=0:
        #print(i)
        tail2.append(i)
        labels2.append(str(j))
    j=j+1


patches, texts, autotexts = plt.pie(tail2,
                                    labels=labels2, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt2.xlabel('Ifmiḍen n teɣzi n tifyar deg uḍris n ulmud')
plt2.show()

# %% [markdown]
# - Pourcentages des Verbes / aspect

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
first=0
tagpos=[]
words=[]
for ligne in open("tagspos.txt",encoding='utf-8'):
    ligne=ligne.strip().replace('\ufeff','')
    tagpos.append(ligne)
for i in tagpos:
    words.append([])
first=0
for ligne in open("corpus-kab.txt",encoding='utf-8'):
    sentence=ligne.strip().replace('\ufeff','').split()

    for word in sentence:
            couple=word.split('/')

            indice=tagpos.index(couple[1])
            words[indice].append(couple[0])


Verbs=['VAF',   #aoriste futur
'VAI',    # aoriste impératif
'VAIT',   #aoriste intensif
'VII',   #impératif intensif
'VP',    # prétérit
'VPA',   #participe aoriste
'VPAIN', #participe aoriste intensif négatif
'VPAIP', #participe aoriste intensif positif
'VPN',   # prétérit négatif
'VPPN',  #participe prétérit négatif
'VPPP',  # participe prétérit positif
'VS'     # verbe subjonctif
]
occurences=[]
for i in Verbs:

 #print(tagpos[index_of_tag1(i,tagpos)],words[index_of_tag1(i,tagpos)])
 occurences.append(len(words[index_of_tag1(i,tagpos)]))

patches, texts, autotexts = plt.pie(occurences,
                                    labels=Verbs, autopct='%.0f%%',
                                    shadow=False, radius=1)
for t in texts:
    t.set_size('smaller')
autotexts[0].set_color('y')

plt.xlabel('Ifmiḍen n yimyagen s tmeẓri(aspect) deg uḍris n ulmud')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-76980c3d4aed> in <module>
#      38
#      39  #print(tagpos[index_of_tag1(i,tagpos)],words[index_of_tag1(i,tagpos)])
# ---> 40  occurences.append(len(words[index_of_tag1(i,tagpos)]))
#      41
#      42 patches, texts, autotexts = plt.pie(occurences,
#
# NameError: name 'index_of_tag1' is not defined

# %% [markdown]
# # représentation grpahique de la succession des classes grammaticales en Kabyle

# %%
import networkx as nx
import numpy as np
import pylab

G = nx.MultiDiGraph()
#list of kabyle tags
tags=[]
i=0
#extraction du tableau des tags

for ligne in open("tagspos.txt",encoding='utf-8'):
     a=ligne.replace('\n',"")
     if (i!=0):
      b=(a,0,())
      tags.append(b)
     i=i+1

edges=[]    # Edges list
#this function renders the tag index in the tags kab array
def index_of_tag(tag):
    l=0
    while l< len(tags):
        c= tags[l]
        b=c[0]
        if (tag==b):
            return (l)
        l=l+1


regexp ='[-A-Zḍčǧḥṛṣẓṭţɣɛ« ».,:1-9a-z]+/[A-Z]+' # regular expression to retreive the couple (tagged wor/tag)

text=""
#Construction du texte global
first=0
number_of_sentences=0
stop=200 # limiter le graphe aux stop premières phrases
for ligne in open("corpus-kab.txt",encoding='utf-8'):
    if (first!=0):
     text=text+' '+ligne.strip()
     number_of_sentences=number_of_sentences+1
     if number_of_sentences== stop:
        break
    first=1

text=text.strip().replace('\n'," ").replace("  "," ").replace("   "," ").replace("\ufeff","")
a=text.split(" ")
i=0
start=0
b=''
while i<len(a)-1:
    iii=b
    #récupérer la paire mot tag
    b=a[i].split("/")  #split a couple
    #print (b[1])

    tuplea=tags[index_of_tag(b[1])] #look for the index of the tag
    #print (tuple)
    number=tuplea[1]+1#increment the tag count
    tuple_tag=tuplea[2]
    list_a=list(tuple_tag)

    if b[1]=='NMP':
        list_a.append(b[0])
    else:
        list_a.append(b[0].lower())
    #print  (list_a)
    tuple_tag=tuple(list_a)
    tags[index_of_tag(b[1])]=(tuplea[0],number,tuple_tag)# update une tag count
    c=a[i+1].split("/") # this is for the last couple word/tag
    if(start==0) and (i==0): # the first start edge : First word in the text or the first edge after a dot
        G.add_edges_from([('Start',b[1])], weight=0)
        edges.append(('Start->'+b[1],1))
        G.add_edges_from([(b[1],c[1])], weight=0) # and create an edge betwen the dot and the previous tags
        edges.append((b[1]+'->'+c[1],1))

        start=1
        #print ('start')
    elif (start==0):
        
         G.add_edges_from([('Start',c[1])], weight=0) # edge start -> next word after a dot .
         start=1
         edges.append(('Start->'+c[1],1))
        

    elif (c[1]=='.') or (c[1]=='!') or(c[1]=='?') :

        G.add_edges_from([(c[1],'Stop')], weight=0) # when a dot is found, create an end
        edges.append((c[1]+'->Stop',1))
        G.add_edges_from([(b[1],c[1])], weight=0) # and create an edge betwen the dot and the previous tags
        edges.append((b[1]+'->'+c[1],1))
        start=0



    else:
        G.add_edges_from([(b[1],c[1])], weight=0) # create and edge between two neighbours
        edges.append((b[1]+'->'+c[1],1))

    i=i+1

# this is for the last tag. We will increment its occurence

tuplea=tags[index_of_tag(c[1])]

number=tuplea[1]+1
tuple_tag=tuplea[2]
list_a=list(tuple_tag)
list_a.append(c[0])
tuple_tag=tuple(list_a)
tags[index_of_tag(c[1])]=(tuplea[0],number,tuple_tag)

#print (tags)
val_map = {}
values = [val_map.get(node, 0.45) for node in G.nodes()]
edge_labels=dict([((u,v,),d['weight'])
                 for u,v,d in G.edges(data=True)])

red_edges = [('Start','NMC'),('NMC','Stop')]
edge_colors = ['black' if not edge in red_edges else 'black' for edge in G.edges()]

pos=nx.spring_layout(G)

options = {
    'node_color': 'blue',
    'node_size': 800,
    'width': 1,
    'arrowstyle': '-|>',
    'arrowsize': 13,
}
color_map = []
j=0
for node in G:
    #print (node)

    if str(node) =='Start' or str(node) =='Stop':
        color_map.append('blue')

    elif (len(str(node))>=4):
        color_map.append('olive')
    elif (len(str(node))==3):
        color_map.append('yellow')
    elif (len(str(node))==2):
        color_map.append('purple')
    else:
        color_map.append('red')
    j=j+1
nx.draw(G,pos, node_color = color_map, node_size=1500,edge_color=edge_colors,edge_cmap=plt.cm.Reds)
#nx.draw_networkx_labels()
#networkx.draw_networkx_labels(graph,node_positions,font_size=16)
#nx.coloring.greedy_color(G, strategy='largest_first')
#nx.draw_networkx(G, arrows=True, **options)
#print (words)i
j=0
labels={}
for i in G.nodes:

    labels[i]=i

nx.draw_networkx_labels(G,pos,labels,font_size=16)

pylab.axis('off')
pylab.show()
